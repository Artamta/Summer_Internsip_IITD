# %%
import nibabel as nb
f_img = nb.load("/Users/ayush/Desktop/project-internsip/Results/6_Aic_CALC/f.nii.gz")
f_img2=nb.load("/Users/ayush/Desktop/project-internsip/Output_Parameter_Maps/Data-1_Simulation-III_SNR-60_f.nii")
f_data = f_img.get_fdata()
f_data2 = f_img2.get_fdata()

print("f_map loaded from NIfTI: min =", f_data.min(), "max =", f_data.max())
print("f_map loaded from NIfTI: min =", f_data2.min(), "max =", f_data2.max())
# Out:
# f_map loaded from NIfTI: min = 0.0 max = 0.014759782869747495
# f_map loaded from NIfTI: min = 0.1113138198852539 max = 1.0779473781585693
